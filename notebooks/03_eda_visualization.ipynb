# %% [markdown]
# # 03 EDA Visualization
#
# This notebook generates required EDA plots and surfaces key relationships.

# %%
from pathlib import Path
import sys

root = Path('..').resolve()
sys.path.append(str(root / 'src'))

from eda_visuals import run_eda

data_path = root / 'data' / 'raw' / 'ibm_hr_attrition.csv'
output_dir = root / 'reports'
run_eda(data_path, output_dir)
# Out:
# EDA plots saved to /home/coder/uni/data_science/final_project/reports

# %% [markdown]
# ### Generated Plots
# The images below are saved in `../reports/`.

# %%
from IPython.display import Image, display
plot_files = [
    'attrition_department.png',
    'age_distribution.png',
    'income_joblevel_box.png',
    'overtime_attrition.png',
    'satisfaction_heatmap.png',
    'correlation_heatmap.png',
    'age_income_scatter.png',
]
for name in plot_files:
    display(Image(filename=str(Path('..') / 'reports' / name)))

# %% [markdown]
# Interactive visualization is available at `../reports/interactive_attrition_department.html`.
