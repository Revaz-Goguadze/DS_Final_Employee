# %% [markdown]
# # 02 Data Preprocessing
#
# This notebook reviews feature engineering and column selection used in modeling.
# Data quality decisions are summarized in `../reports/data_quality_report.md`.

# %%
from pathlib import Path
import sys

root = Path('..').resolve()
sys.path.append(str(root / 'src'))

from modeling import load_and_preprocess

data_path = root / 'data' / 'raw' / 'ibm_hr_attrition.csv'
X, y, categorical_cols, numerical_cols = load_and_preprocess(data_path)
X.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  ...  RelationshipSatisfaction_outlier  \
# 0  Female          94  ...                                 0
# ...

# %%
categorical_cols
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime',
#  'AgeGroup']

# %%
numerical_cols
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'TotalSatisfaction',
#  'Age_outlier',
#  'DailyRate_outlier',
#  'DistanceFromHome_outlier',
#  'Education_outlier',
#  'EnvironmentSatisfaction_outlier',
#  'HourlyRate_outlier',
#  'JobInvolvement_outlier',
#  'JobLevel_outlier',
#  'JobSatisfaction_outlier',
#  'MonthlyIncome_outlier',
#  'MonthlyRate_outlier',
#  'NumCompaniesWorked_outlier',
#  'PercentSalaryHike_outlier',
#  'PerformanceRating_outlier',
#  'RelationshipSatisfaction_outlier',
#  'StockOptionLevel_outlier',
# ...

# %% [markdown]
# ### Feature Engineering Summary
# - `AgeGroup` derived from `Age` bins.
# - `TotalSatisfaction` is the sum of available satisfaction metrics.
# - Non-informative columns removed during modeling: `EmployeeNumber`, `Over18`, `StandardHours`, `EmployeeCount`.
